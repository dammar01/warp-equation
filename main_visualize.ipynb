# %% [markdown]
# ### Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# setup
from setup.visualize import VisualizeData


UID = "800547376"


RANK_TYPE = "5"
# RANK_TYPE = "4"

visualize = VisualizeData(UID, RANK_TYPE)

# %%
visualize.distribute_item()

# %%
visualize.pity_statistic()

# %%
visualize.pity_rate()

# %%
visualize.pity_change()

# %%
visualize.frequency_event_by_week()

# %%
visualize.check_correlation(
    ["id", "gacha_id", "gacha_type", "item_id", "item_type", "datetime", "year"]
)
